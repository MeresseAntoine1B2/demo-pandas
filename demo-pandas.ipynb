# %%
import pandas as pd

# %%
# charger les données depuis un fichier csv
df = pd.read_csv('titles.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# visualiser les 5 premières lignes du jeu de données
df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# ...

# %%
# Avoir des informations plus précises sur le jeu de données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5806 non-null   object
#  1   title                 5805 non-null   object
#  2   type                  5806 non-null   object
#  3   description           5788 non-null   object
#  4   release_year          5806 non-null   int64
#  5   age_certification     3196 non-null   object
#  6   runtime               5806 non-null   int64
#  7   genres                5806 non-null   object
#  8   production_countries  5806 non-null   object
#  9   seasons               2047 non-null   float64
#  10  imdb_id               5362 non-null   object
#  11  imdb_score            5283 non-null   float64
#  12  imdb_votes            5267 non-null   float64
#  13  tmdb_popularity       5712 non-null   float64
#  14  tmdb_score            5488 non-null   float64
# ...

# %%
# Afficher les valeurs de la colonne release_year v1
df.release_year
# Out:
# 0       1945
# 1       1976
# 2       1975
# 3       1979
# 4       1973
#         ...
# 5801    2021
# 5802    2021
# 5803    2021
# 5804    2021
# 5805    2021
# Name: release_year, Length: 5806, dtype: int64

# %%
type(df.release_year)
# Out:
# pandas.core.series.Series

# %%
# Afficher les valeurs de la colonne release_year v2
df['release_year']
# Out:
# 0       1945
# 1       1976
# 2       1975
# 3       1979
# 4       1973
#         ...
# 5801    2021
# 5802    2021
# 5803    2021
# 5804    2021
# 5805    2021
# Name: release_year, Length: 5806, dtype: int64

# %%
# S'assurer que les résultats soient équivalents
assert (df['release_year'] == df.release_year).all()

# %%
# Afficher les valeurs de la colonne release_year v3 méthode .loc
df.loc[:,'release_year']
# Out:
# 0       1945
# 1       1976
# 2       1975
# 3       1979
# 4       1973
#         ...
# 5801    2021
# 5802    2021
# 5803    2021
# 5804    2021
# 5805    2021
# Name: release_year, Length: 5806, dtype: int64

# %%
df.loc[0,'release_year']
# Out:
# 1945

# %%
# Afficher les valeurs de la colonne release_year v4 méthode .iloc
# cette méthode nécessite de spécifié la position et non le nom de l'index/colonne
df.iloc[0, 4]
# Out:
# 1945

# %%
# Condition : Sélection des lignes pour lesquelles l'année de sortie est supérieur à 1975
# le résultat est une série avec des valeurs booléennes
df['release_year'] > 1975
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 5801     True
# 5802     True
# 5803     True
# 5804     True
# 5805     True
# Name: release_year, Length: 5806, dtype: bool

# %%
# on peut passer se résultat dans une variable mask
mask = df['release_year'] > 1975

# %%
# je passe ce masque dans un .loc
df.loc[mask]
# Out:
#              id                                      title   type  \
# 1       tm84618                                Taxi Driver  MOVIE
# 3       tm70993                              Life of Brian  MOVIE
# 8       tm98978                            The Blue Lagoon  MOVIE
# 12      tm69778  Lupin the Third: The Castle of Cagliostro  MOVIE
# 13      tm69997             Richard Pryor: Live in Concert  MOVIE
# ...         ...                                        ...    ...
# 5801  tm1014599                                  Fine Wine  MOVIE
# 5802  tm1108171                             Edis Starlight  MOVIE
# 5803  tm1045018                                      Clash  MOVIE
# 5804  tm1098060                             Shadow Parties  MOVIE
# 5805   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
mask2 = df['runtime'] < 80

# %%
mask
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 5801     True
# 5802     True
# 5803     True
# 5804     True
# 5805     True
# Name: release_year, Length: 5806, dtype: bool

# %%
mask2
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5801    False
# 5802     True
# 5803    False
# 5804    False
# 5805     True
# Name: runtime, Length: 5806, dtype: bool

# %%
#Combinaison des deux masques grâce à un opérateur &
combo_mask =mask & mask2

# %%
df.loc[combo_mask]
# Out:
#              id                               title   type  \
# 13      tm69997      Richard Pryor: Live in Concert  MOVIE
# 37     tm259855       We Are All for the Fatherland  MOVIE
# 47      ts20681                            Seinfeld   SHOW
# 55      ts22082                        Knight Rider   SHOW
# 57      ts21715                    Thomas & Friends   SHOW
# ...         ...                                 ...    ...
# 5794   ts297061                     Masameer County   SHOW
# 5796   ts286386                         The Big Day   SHOW
# 5799   ts307884                          HQ Barbers   SHOW
# 5802  tm1108171                      Edis Starlight  MOVIE
# 5805   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 13    Richard Pryor delivers monologues on race, sex...          1979
# 37    After the 1978 Israeli invasion of Lebanon, ch...          1979
# ...

# %%
df.loc[mask&mask2]
# Out:
#              id                               title   type  \
# 13      tm69997      Richard Pryor: Live in Concert  MOVIE
# 37     tm259855       We Are All for the Fatherland  MOVIE
# 47      ts20681                            Seinfeld   SHOW
# 55      ts22082                        Knight Rider   SHOW
# 57      ts21715                    Thomas & Friends   SHOW
# ...         ...                                 ...    ...
# 5794   ts297061                     Masameer County   SHOW
# 5796   ts286386                         The Big Day   SHOW
# 5799   ts307884                          HQ Barbers   SHOW
# 5802  tm1108171                      Edis Starlight  MOVIE
# 5805   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 13    Richard Pryor delivers monologues on race, sex...          1979
# 37    After the 1978 Israeli invasion of Lebanon, ch...          1979
# ...

# %%
import missingno as msno
# Visualisation des valeurs manquantes grâce à la libraire missingno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# Afficher un résumé statistique du jeu de données
# Ces données seront affichées uniquement pour les colonnes dans le type de valeur est numérique
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06
#
#        tmdb_popularity   tmdb_score
# count      5712.000000  5488.000000
# mean         22.525660     6.818039
# std          68.849177     1.171560
# min           0.009442     0.500000
# 25%           3.155250     6.100000
# 50%           7.478000     6.900000
# 75%          17.775750     7.500000
# ...

# %%
# Afficher la moyenne pour runtime
df.runtime.mean()
# Out:
# 77.64398897692043

# %%
# Afficher l'écart type pour runtime
df.runtime.std()
# Out:
# 39.4741602050739

# %%
# Afficher la médiane pour runtime
df.runtime.median()
# Out:
# 84.0

# %%
# Afficher les valeurs uniques que puissent prendre la colonne type
df.type.unique()
# Out:
# array(['SHOW', 'MOVIE'], dtype=object)

# %%
# Le nombre de valeurs uniques que puissent prendre la colonne title
len(df.title.unique())
# Out:
# 5752

# %%
repartion_type = df.type.value_counts()

# %%
# Compter le nombre d'occurence pour chaque valeur
df.type.value_counts()
# Out:
# MOVIE    3759
# SHOW     2047
# Name: type, dtype: int64

# %%
# Affichage graphique du résultat précédeng à l'aide d'un diagramme à barres
repartion_type.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
mask_contain_the = df.title.str.contains('The')

# %%
mask_contain_the.isnull().sum()
# Out:
# 1

# %%
df.loc[mask_contain_the]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jeremyvangansbeg/Desktop/demo-pandas/demo-pandas.ipynb Cell 35' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jeremyvangansbeg/Desktop/demo-pandas/demo-pandas.ipynb#ch0000037?line=0'>1</a> df.loc[mask_contain_the]
#
# File /opt/miniconda3/envs/jvp/lib/python3.10/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/miniconda3/envs/jvp/lib/python3.10/site-packages/pandas/core/indexing.py:1181, in _LocIndexer._getitem_axis(self, key, axis)
#    1179     self._validate_key(key, axis)
#    1180     return self._get_slice_axis(key, axis=axis)
# -> 1181 elif com.is_bool_indexer(key):
# ...

# %%
df_nona = df.dropna(subset='title')

# %%
df_nona.loc[df_nona.title.str.contains('The')]
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 4      tm190788                               The Exorcist  MOVIE
# 8       tm98978                            The Blue Lagoon  MOVIE
# 10      tm67378                          The Professionals  MOVIE
# 11      tm44204                       The Guns of Navarone  MOVIE
# ...         ...                                        ...    ...
# 5783  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5784   tm993616                 The Tambour of Retribution  MOVIE
# 5786   tm851599                      Tersanjung: The Movie  MOVIE
# 5795   tm878575                        The Heartbreak Club  MOVIE
# 5796   ts286386                                The Big Day   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
df['type2'] = 'vegetal'

# %%
df.loc[df['type2'] == 'vegetal']
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...
